# %% [markdown]
# # ML_project 1_Maktabkhoone

# %% [markdown]
# ![Screenshot%20from%202022-08-09%2021-28-54.png](attachment:Screenshot%20from%202022-08-09%2021-28-54.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pylab as pl
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## reading data

# %%
df= pd.read_csv('1632300362534233.csv')
df
# Out:
#      Area  Room  Parking  Warehouse  Elevator             Address  \
# 0      63     1     True       True      True             Shahran
# 1      60     1     True       True      True             Shahran
# 2      79     2     True       True      True              Pardis
# 3      95     2     True       True      True       Shahrake Qods
# 4     123     2     True       True      True      Shahrake Gharb
# ...   ...   ...      ...        ...       ...                 ...
# 3474   86     2     True       True      True  Southern Janatabad
# 3475   83     2     True       True      True            Niavaran
# 3476   75     2    False      False     False              Parand
# 3477  105     2     True       True      True              Dorous
# 3478   82     2    False       True      True              Parand
#
#              Price  Price(USD)
# 0     1.850000e+09    61666.67
# 1     1.850000e+09    61666.67
# 2     5.500000e+08    18333.33
# 3     9.025000e+08    30083.33
# ...

# %% [markdown]
# ## Data Exploration

# %%
df.describe()
# Out:
#               Room         Price    Price(USD)
# count  3479.000000  3.479000e+03  3.479000e+03
# mean      2.079908  5.359023e+09  1.786341e+05
# std       0.758275  8.099935e+09  2.699978e+05
# min       0.000000  3.600000e+06  1.200000e+02
# 25%       2.000000  1.418250e+09  4.727500e+04
# 50%       2.000000  2.900000e+09  9.666667e+04
# 75%       2.000000  6.000000e+09  2.000000e+05
# max       5.000000  9.240000e+10  3.080000e+06

# %%
df.head(10)
# Out:
#   Area  Room  Parking  Warehouse  Elevator                     Address  \
# 0   63     1     True       True      True                     Shahran
# 1   60     1     True       True      True                     Shahran
# 2   79     2     True       True      True                      Pardis
# 3   95     2     True       True      True               Shahrake Qods
# 4  123     2     True       True      True              Shahrake Gharb
# 5   70     2     True       True     False  North Program Organization
# 6   87     2     True       True      True                      Pardis
# 7   59     1     True       True      True                     Shahran
# 8   54     2     True       True     False                    Andisheh
# 9   71     1     True       True      True      West Ferdows Boulevard
#
#           Price  Price(USD)
# 0  1.850000e+09    61666.67
# 1  1.850000e+09    61666.67
# 2  5.500000e+08    18333.33
# 3  9.025000e+08    30083.33
# 4  7.000000e+09   233333.33
# ...

# %%
df.isnull().values.any()
# Out:
# True

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# ### Missing values

# %%
df.isnull().sum()
# Out:
# Area           0
# Room           0
# Parking        0
# Warehouse      0
# Elevator       0
# Address       23
# Price          0
# Price(USD)     0
# dtype: int64

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# Area          0
# Room          0
# Parking       0
# Warehouse     0
# Elevator      0
# Address       0
# Price         0
# Price(USD)    0
# dtype: int64

# %%
df.shape
# Out:
# (3456, 8)

# %%
#Drop USD Price
df=df.drop(labels='Price(USD)', axis=1)
df
# Out:
#      Area  Room  Parking  Warehouse  Elevator             Address  \
# 0      63     1     True       True      True             Shahran
# 1      60     1     True       True      True             Shahran
# 2      79     2     True       True      True              Pardis
# 3      95     2     True       True      True       Shahrake Qods
# 4     123     2     True       True      True      Shahrake Gharb
# ...   ...   ...      ...        ...       ...                 ...
# 3474   86     2     True       True      True  Southern Janatabad
# 3475   83     2     True       True      True            Niavaran
# 3476   75     2    False      False     False              Parand
# 3477  105     2     True       True      True              Dorous
# 3478   82     2    False       True      True              Parand
#
#              Price
# 0     1.850000e+09
# 1     1.850000e+09
# 2     5.500000e+08
# 3     9.025000e+08
# 4     7.000000e+09
# ...            ...
# 3474  3.500000e+09
# ...

# %% [markdown]
# ### outliers

# %%
df.hist(column='Price')
# Out:
# array([[<AxesSubplot:title={'center':'Price'}>]], dtype=object)

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np

# copy the data
df_sklearn = df.copy()

# apply normalization techniques
column = 'Price'
df_sklearn[column] = MinMaxScaler().fit_transform(np.array(df_sklearn[column]).reshape(-1,1))

# view normalized data
display(df_sklearn)
# Out:
#      Area  Room  Parking  Warehouse  Elevator             Address     Price
# 0      63     1     True       True      True             Shahran  0.019983
# 1      60     1     True       True      True             Shahran  0.019983
# 2      79     2     True       True      True              Pardis  0.005914
# 3      95     2     True       True      True       Shahrake Qods  0.009729
# 4     123     2     True       True      True      Shahrake Gharb  0.075722
# ...   ...   ...      ...        ...       ...                 ...       ...
# 3474   86     2     True       True      True  Southern Janatabad  0.037841
# 3475   83     2     True       True      True            Niavaran  0.073557
# 3476   75     2    False      False     False              Parand  0.003911
# 3477  105     2     True       True      True              Dorous  0.060569
# 3478   82     2    False       True      True              Parand  0.003857
#
# [3456 rows x 7 columns]

# %%
df_sklearn[column].plot(kind='hist', logy=True,ylabel='Counts',xlabel='Price')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df_sklearn[column].plot(kind='area',ylabel='Price')
# Out:
# <AxesSubplot:ylabel='Price'>

# %%
df_sklearn.plot(x='Address', y='Price',figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Address'>

# %%
df_sklearn[column].describe()
# Out:
# count    3456.000000
# mean        0.058188
# std         0.087901
# min         0.000000
# 25%         0.015330
# 50%         0.031348
# 75%         0.064899
# max         1.000000
# Name: Price, dtype: float64

# %%
df_sklearn.boxplot(column='Price',color='b')
# Out:
# <AxesSubplot:>

# %%
df_sklearn['Price'].quantile(0.99)
# Out:
# 0.4328783372512349

# %%
df['Price'].quantile(0.75)
# Out:
# 6000000000.0

# %%
def remove_outlier(df_in, col_name):
    q1 = df_in[col_name].quantile(0.25)
    q3 = df_in[col_name].quantile(0.75)
    iqr = q3-q1 #Interquartile range
    fence_low  = q1-1.5*iqr
    fence_high = q3+1.5*iqr
    df_out = df_in.loc[(df_in[col_name] > fence_low) & (df_in[col_name] < fence_high)]
    return df_out

# %%
df_sklearn=remove_outlier(df_sklearn,'Price')

# %%
df_sklearn.describe(), df.shape, df_sklearn.shape
# Out:
# (              Room        Price
#  count  3146.000000  3146.000000
#  mean      1.968531     0.037386
#  std       0.664303     0.031275
#  min       0.000000     0.000000
#  25%       2.000000     0.013736
#  50%       2.000000     0.027018
#  75%       2.000000     0.049747
#  max       5.000000     0.139036,
#  (3456, 7),
#  (3146, 7))

# %%
df_sklearn['Price'].plot(kind='box',figsize=(5,10))
# Out:
# <AxesSubplot:>
